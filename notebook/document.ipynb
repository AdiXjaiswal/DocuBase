# %% [markdown]
# ### Data Ingestion

# %%
# Document Structure
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="This is a sample document content.", 
)
doc
# Out:
# Document(metadata={}, page_content='This is a sample document content.')

# %%
import pymupdf

# %%
# directory loader
from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders import PyMuPDFLoader

dir_loader = DirectoryLoader(
    "../data",  # Replace with the path to your directory
    glob="**/*.pdf",  # Adjust the glob pattern as needed
    # loader_cls=pymupdf.PyMuPDFLoader,  # Use PyMuPDFLoader for PDF files
    loader_cls=PyMuPDFLoader,  # Use PyMuPDFLoader for PDF files
    show_progress=True
)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12008\52981628.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import DirectoryLoader

# %%
dir_loader.load()[0]
# Out:
# 100%|██████████| 2/2 [00:00<00:00,  9.66it/s]
# Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2025-09-21T10:02:46+00:00', 'source': '..\\data\\Machine_Learning_Unit_2.pdf', 'file_path': '..\\data\\Machine_Learning_Unit_2.pdf', 'total_pages': 46, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-14T21:03:01+05:30', 'trapped': '', 'modDate': "D:20251214210301+05'30'", 'creationDate': 'D:20250921100246Z', 'page': 0}, page_content='UNIT 2 Linear and Logistic Regression,\nBayesian Learning, Support Vector Machines\nMLT, BCS 055\n1')
